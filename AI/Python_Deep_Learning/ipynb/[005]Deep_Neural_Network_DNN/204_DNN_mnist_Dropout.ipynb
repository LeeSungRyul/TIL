# %% [markdown]
# # MNIST - Categorical Classification
# > # Dropout
# ## Import Tensorflow & Keras

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# * import Keras

# %%
import keras

keras.__version__
# Out:
# '2.4.3'

# %% [markdown]
# # I. MNIST Data_Set Load

# %%
from keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# # II. Data Preprocessing

# %% [markdown]
# > ## 1) Reshape and Normalization

# %% [markdown]
# * reshape

# %%
X_train = X_train.reshape((60000, 28 * 28))
X_test = X_test.reshape((10000, 28 * 28))

# %% [markdown]
# * Normalization

# %%
X_train = X_train.astype(float) / 255
X_test = X_test.astype(float) / 255

# %% [markdown]
# > ## 2) One Hot Encoding

# %%
from keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# # III. MNIST Keras Modeling

# %% [markdown]
# > ## 1) Model Define

# %% [markdown]
# * 모델 신경망 구조 정의
#  - 2개의 Hidden Layers & 768개의 Nodes
#  - Model Capacity는 기존과 동일
#  - Dropout Layers 적용

# %%
from keras import models
from keras import layers

mnist = models.Sequential()
mnist.add(layers.Dense(512, activation = 'relu', input_shape=(28 * 28,)))
mnist.add(layers.Dropout(0.4))
mnist.add(layers.Dense(256, activation = 'relu'))
mnist.add(layers.Dropout(0.2))
mnist.add(layers.Dense(10, activation = 'softmax'))

# %% [markdown]
# * 모델 구조 확인

# %%
mnist.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               401920
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 535,818
# Trainable params: 535,818
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %% [markdown]
# * 모델 학습방법 설정

# %%
mnist.compile(loss = 'categorical_crossentropy',
              optimizer = 'rmsprop',
              metrics = ['accuracy'])

# %% [markdown]
# > ## 3) Model Fit

# %% [markdown]
# * 약 3분

# %%
# %%time

Hist_mnist = mnist.fit(X_train, y_train,
                       epochs = 100,
                       batch_size = 128,
                       validation_split = 0.2)
# Out:
# Epoch 1/100
# 375/375 [==============================] - 5s 4ms/step - loss: 0.5347 - accuracy: 0.8320 - val_loss: 0.1287 - val_accuracy: 0.9616
# Epoch 2/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1526 - accuracy: 0.9543 - val_loss: 0.1055 - val_accuracy: 0.9676
# Epoch 3/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1106 - accuracy: 0.9664 - val_loss: 0.0930 - val_accuracy: 0.9720
# Epoch 4/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0929 - accuracy: 0.9726 - val_loss: 0.0840 - val_accuracy: 0.9762
# Epoch 5/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0794 - accuracy: 0.9749 - val_loss: 0.0918 - val_accuracy: 0.9759
# Epoch 6/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0687 - accuracy: 0.9793 - val_loss: 0.0886 - val_accuracy: 0.9763
# Epoch 7/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0642 - accuracy: 0.9804 - val_loss: 0.0899 - val_accuracy: 0.9771
# Epoch 8/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0553 - accuracy: 0.9827 - val_loss: 0.0887 - val_accuracy: 0.9800
# Epoch 9/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0547 - accuracy: 0.9840 - val_loss: 0.0926 - val_accuracy: 0.9794
# Epoch 10/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0532 - accuracy: 0.9848 - val_loss: 0.0934 - val_accuracy: 0.9796
# Epoch 11/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0455 - accuracy: 0.9858 - val_loss: 0.1004 - val_accuracy: 0.9793
# Epoch 12/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0404 - accuracy: 0.9876 - val_loss: 0.0963 - val_accuracy: 0.9783
# Epoch 13/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0404 - accuracy: 0.9876 - val_loss: 0.1059 - val_accuracy: 0.9787
# Epoch 14/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0357 - accuracy: 0.9892 - val_loss: 0.0979 - val_accuracy: 0.9801
# Epoch 15/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0352 - accuracy: 0.9900 - val_loss: 0.1110 - val_accuracy: 0.9805
# Epoch 16/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0336 - accuracy: 0.9897 - val_loss: 0.1110 - val_accuracy: 0.9805
# Epoch 17/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0339 - accuracy: 0.9905 - val_loss: 0.1150 - val_accuracy: 0.9786
# Epoch 18/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0330 - accuracy: 0.9902 - val_loss: 0.1183 - val_accuracy: 0.9806
# Epoch 19/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0309 - accuracy: 0.9910 - val_loss: 0.1127 - val_accuracy: 0.9811
# Epoch 20/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0258 - accuracy: 0.9926 - val_loss: 0.1165 - val_accuracy: 0.9817
# Epoch 21/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0284 - accuracy: 0.9917 - val_loss: 0.1170 - val_accuracy: 0.9807
# Epoch 22/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0334 - accuracy: 0.9910 - val_loss: 0.1232 - val_accuracy: 0.9814
# Epoch 23/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0282 - accuracy: 0.9919 - val_loss: 0.1251 - val_accuracy: 0.9824
# Epoch 24/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0272 - accuracy: 0.9924 - val_loss: 0.1266 - val_accuracy: 0.9817
# Epoch 25/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0303 - accuracy: 0.9916 - val_loss: 0.1198 - val_accuracy: 0.9833
# Epoch 26/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0259 - accuracy: 0.9932 - val_loss: 0.1307 - val_accuracy: 0.9820
# Epoch 27/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0283 - accuracy: 0.9924 - val_loss: 0.1264 - val_accuracy: 0.9817
# Epoch 28/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0242 - accuracy: 0.9938 - val_loss: 0.1236 - val_accuracy: 0.9818
# Epoch 29/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0231 - accuracy: 0.9928 - val_loss: 0.1327 - val_accuracy: 0.9815
# Epoch 30/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0238 - accuracy: 0.9930 - val_loss: 0.1519 - val_accuracy: 0.9812
# Epoch 31/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0233 - accuracy: 0.9931 - val_loss: 0.1350 - val_accuracy: 0.9824
# Epoch 32/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0242 - accuracy: 0.9937 - val_loss: 0.1537 - val_accuracy: 0.9807
# Epoch 33/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0247 - accuracy: 0.9931 - val_loss: 0.1479 - val_accuracy: 0.9827
# Epoch 34/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0220 - accuracy: 0.9939 - val_loss: 0.1447 - val_accuracy: 0.9813
# Epoch 35/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0231 - accuracy: 0.9936 - val_loss: 0.1481 - val_accuracy: 0.9811
# Epoch 36/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0240 - accuracy: 0.9940 - val_loss: 0.1561 - val_accuracy: 0.9811
# Epoch 37/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0261 - accuracy: 0.9936 - val_loss: 0.1483 - val_accuracy: 0.9816
# Epoch 38/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0238 - accuracy: 0.9934 - val_loss: 0.1422 - val_accuracy: 0.9819
# Epoch 39/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0228 - accuracy: 0.9937 - val_loss: 0.1549 - val_accuracy: 0.9823
# Epoch 40/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0206 - accuracy: 0.9945 - val_loss: 0.1530 - val_accuracy: 0.9829
# Epoch 41/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0203 - accuracy: 0.9947 - val_loss: 0.1652 - val_accuracy: 0.9818
# Epoch 42/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0221 - accuracy: 0.9943 - val_loss: 0.1588 - val_accuracy: 0.9823
# Epoch 43/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0206 - accuracy: 0.9945 - val_loss: 0.1662 - val_accuracy: 0.9822
# Epoch 44/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0230 - accuracy: 0.9940 - val_loss: 0.1637 - val_accuracy: 0.9827
# Epoch 45/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0190 - accuracy: 0.9950 - val_loss: 0.1621 - val_accuracy: 0.9832
# Epoch 46/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0179 - accuracy: 0.9947 - val_loss: 0.1703 - val_accuracy: 0.9828
# Epoch 47/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0214 - accuracy: 0.9949 - val_loss: 0.1385 - val_accuracy: 0.9829
# Epoch 48/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0190 - accuracy: 0.9950 - val_loss: 0.1681 - val_accuracy: 0.9821
# Epoch 49/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0188 - accuracy: 0.9952 - val_loss: 0.1611 - val_accuracy: 0.9827
# Epoch 50/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0188 - accuracy: 0.9956 - val_loss: 0.1733 - val_accuracy: 0.9827
# Epoch 51/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0182 - accuracy: 0.9953 - val_loss: 0.1742 - val_accuracy: 0.9825
# Epoch 52/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0193 - accuracy: 0.9951 - val_loss: 0.1798 - val_accuracy: 0.9827
# Epoch 53/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0211 - accuracy: 0.9954 - val_loss: 0.1849 - val_accuracy: 0.9833
# Epoch 54/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0187 - accuracy: 0.9954 - val_loss: 0.1809 - val_accuracy: 0.9819
# Epoch 55/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0206 - accuracy: 0.9951 - val_loss: 0.1776 - val_accuracy: 0.9826
# Epoch 56/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0197 - accuracy: 0.9952 - val_loss: 0.1687 - val_accuracy: 0.9828
# Epoch 57/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0209 - accuracy: 0.9956 - val_loss: 0.1930 - val_accuracy: 0.9824
# Epoch 58/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0189 - accuracy: 0.9957 - val_loss: 0.1877 - val_accuracy: 0.9816
# Epoch 59/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0213 - accuracy: 0.9949 - val_loss: 0.2025 - val_accuracy: 0.9827
# Epoch 60/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0206 - accuracy: 0.9953 - val_loss: 0.2007 - val_accuracy: 0.9830
# Epoch 61/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0180 - accuracy: 0.9956 - val_loss: 0.1908 - val_accuracy: 0.9827
# Epoch 62/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0216 - accuracy: 0.9955 - val_loss: 0.1901 - val_accuracy: 0.9833
# Epoch 63/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0199 - accuracy: 0.9954 - val_loss: 0.1843 - val_accuracy: 0.9833
# Epoch 64/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0215 - accuracy: 0.9951 - val_loss: 0.1898 - val_accuracy: 0.9827
# Epoch 65/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0169 - accuracy: 0.9963 - val_loss: 0.1896 - val_accuracy: 0.9836
# Epoch 66/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0180 - accuracy: 0.9959 - val_loss: 0.1808 - val_accuracy: 0.9825
# Epoch 67/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0180 - accuracy: 0.9957 - val_loss: 0.1976 - val_accuracy: 0.9818
# Epoch 68/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0179 - accuracy: 0.9961 - val_loss: 0.2011 - val_accuracy: 0.9832
# Epoch 69/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0168 - accuracy: 0.9962 - val_loss: 0.1982 - val_accuracy: 0.9822
# Epoch 70/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0164 - accuracy: 0.9966 - val_loss: 0.1963 - val_accuracy: 0.9827
# Epoch 71/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0208 - accuracy: 0.9957 - val_loss: 0.2008 - val_accuracy: 0.9821
# Epoch 72/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0163 - accuracy: 0.9968 - val_loss: 0.2116 - val_accuracy: 0.9820
# Epoch 73/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0197 - accuracy: 0.9956 - val_loss: 0.2106 - val_accuracy: 0.9817
# Epoch 74/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0202 - accuracy: 0.9955 - val_loss: 0.2005 - val_accuracy: 0.9826
# Epoch 75/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0156 - accuracy: 0.9963 - val_loss: 0.2053 - val_accuracy: 0.9827
# Epoch 76/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0208 - accuracy: 0.9958 - val_loss: 0.2142 - val_accuracy: 0.9822
# Epoch 77/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0152 - accuracy: 0.9965 - val_loss: 0.2040 - val_accuracy: 0.9829
# Epoch 78/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0221 - accuracy: 0.9959 - val_loss: 0.2015 - val_accuracy: 0.9833
# Epoch 79/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0219 - accuracy: 0.9953 - val_loss: 0.2208 - val_accuracy: 0.9818
# Epoch 80/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0248 - accuracy: 0.9955 - val_loss: 0.2238 - val_accuracy: 0.9827
# Epoch 81/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0163 - accuracy: 0.9964 - val_loss: 0.2109 - val_accuracy: 0.9825
# Epoch 82/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0212 - accuracy: 0.9951 - val_loss: 0.2334 - val_accuracy: 0.9824
# Epoch 83/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0146 - accuracy: 0.9970 - val_loss: 0.2210 - val_accuracy: 0.9824
# Epoch 84/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0197 - accuracy: 0.9959 - val_loss: 0.2175 - val_accuracy: 0.9830
# Epoch 85/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0133 - accuracy: 0.9969 - val_loss: 0.2030 - val_accuracy: 0.9835
# Epoch 86/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0171 - accuracy: 0.9967 - val_loss: 0.2115 - val_accuracy: 0.9828
# Epoch 87/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0159 - accuracy: 0.9966 - val_loss: 0.2141 - val_accuracy: 0.9827
# Epoch 88/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0163 - accuracy: 0.9962 - val_loss: 0.2165 - val_accuracy: 0.9839
# Epoch 89/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0192 - accuracy: 0.9956 - val_loss: 0.2157 - val_accuracy: 0.9839
# Epoch 90/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0191 - accuracy: 0.9961 - val_loss: 0.2083 - val_accuracy: 0.9834
# Epoch 91/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0151 - accuracy: 0.9967 - val_loss: 0.2226 - val_accuracy: 0.9832
# Epoch 92/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0179 - accuracy: 0.9961 - val_loss: 0.2014 - val_accuracy: 0.9837
# Epoch 93/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0163 - accuracy: 0.9964 - val_loss: 0.2131 - val_accuracy: 0.9829
# Epoch 94/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0192 - accuracy: 0.9961 - val_loss: 0.2407 - val_accuracy: 0.9826
# Epoch 95/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0158 - accuracy: 0.9968 - val_loss: 0.2408 - val_accuracy: 0.9817
# Epoch 96/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0178 - accuracy: 0.9961 - val_loss: 0.2129 - val_accuracy: 0.9837
# Epoch 97/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0152 - accuracy: 0.9961 - val_loss: 0.2398 - val_accuracy: 0.9843
# Epoch 98/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0188 - accuracy: 0.9962 - val_loss: 0.2495 - val_accuracy: 0.9828
# Epoch 99/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0172 - accuracy: 0.9966 - val_loss: 0.2337 - val_accuracy: 0.9838
# Epoch 100/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0178 - accuracy: 0.9968 - val_loss: 0.2110 - val_accuracy: 0.9839
# CPU times: user 2min 5s, sys: 17.9 s, total: 2min 23s
# Wall time: 1min 59s

# %% [markdown]
# > ## 4) 학습 결과 시각화

# %% [markdown]
# * Loss Visualization

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_mnist.history['loss']) + 1)

plt.figure(figsize = (9, 6))
plt.plot(epochs, Hist_mnist.history['loss'])
plt.plot(epochs, Hist_mnist.history['val_loss'])
plt.ylim(0, 0.4)
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()
plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %% [markdown]
# * Loss & Accuracy

# %%
loss, accuracy = mnist.evaluate(X_test, y_test)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1926 - accuracy: 0.9849
# Loss = 0.19264
# Accuracy = 0.98490

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
