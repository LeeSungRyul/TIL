# %% [markdown]
# # MNIST - Categorical Classification
# > # Model Capacity
# ## Import Tensorflow & Keras

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# * import Keras

# %%
import keras

keras.__version__
# Out:
# '2.4.3'

# %% [markdown]
# # I. MNIST Data_Set Load

# %%
from keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# # II. Data Preprocessing

# %% [markdown]
# > ## 1) Reshape and Normalization

# %% [markdown]
# * reshape

# %%
X_train = X_train.reshape((60000, 28 * 28))
X_test = X_test.reshape((10000, 28 * 28))

# %% [markdown]
# * Normalization

# %%
X_train = X_train.astype(float) / 255
X_test = X_test.astype(float) / 255

# %% [markdown]
# > ## 2) One Hot Encoding

# %%
from keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# # III. MNIST Keras Modeling

# %% [markdown]
# > ## 1) Model Define

# %% [markdown]
# * 모델 신경망 구조 정의
#  - 1개의 Hidden Layer & 256개의 Nodes
#  - Model Capacity 낮게 조정

# %%
from keras import models
from keras import layers

mnist = models.Sequential()
mnist.add(layers.Dense(256, activation = 'relu', input_shape=(28 * 28,)))
mnist.add(layers.Dense(10, activation = 'softmax'))

# %% [markdown]
# * 모델 구조 확인

# %%
mnist.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 256)               200960
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 203,530
# Trainable params: 203,530
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %% [markdown]
# * 모델 학습방법 설정

# %%
mnist.compile(loss = 'categorical_crossentropy',
              optimizer = 'rmsprop',
              metrics = ['accuracy'])

# %% [markdown]
# > ## 3) Model Fit

# %% [markdown]
# * 약 2분

# %%
# %%time

Hist_mnist = mnist.fit(X_train, y_train,
                       epochs = 100,
                       batch_size = 128,
                       validation_split = 0.2)
# Out:
# Epoch 1/100
# 375/375 [==============================] - 5s 4ms/step - loss: 0.5336 - accuracy: 0.8488 - val_loss: 0.1715 - val_accuracy: 0.9532
# Epoch 2/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1561 - accuracy: 0.9539 - val_loss: 0.1252 - val_accuracy: 0.9622
# Epoch 3/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1005 - accuracy: 0.9700 - val_loss: 0.1114 - val_accuracy: 0.9672
# Epoch 4/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0752 - accuracy: 0.9783 - val_loss: 0.0974 - val_accuracy: 0.9705
# Epoch 5/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0578 - accuracy: 0.9835 - val_loss: 0.0908 - val_accuracy: 0.9729
# Epoch 6/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0470 - accuracy: 0.9865 - val_loss: 0.0838 - val_accuracy: 0.9755
# Epoch 7/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0391 - accuracy: 0.9897 - val_loss: 0.0833 - val_accuracy: 0.9768
# Epoch 8/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0278 - accuracy: 0.9924 - val_loss: 0.0893 - val_accuracy: 0.9736
# Epoch 9/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0222 - accuracy: 0.9937 - val_loss: 0.0893 - val_accuracy: 0.9761
# Epoch 10/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0189 - accuracy: 0.9950 - val_loss: 0.0902 - val_accuracy: 0.9763
# Epoch 11/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0144 - accuracy: 0.9965 - val_loss: 0.0885 - val_accuracy: 0.9774
# Epoch 12/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0116 - accuracy: 0.9973 - val_loss: 0.0883 - val_accuracy: 0.9773
# Epoch 13/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0097 - accuracy: 0.9973 - val_loss: 0.0903 - val_accuracy: 0.9788
# Epoch 14/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0075 - accuracy: 0.9984 - val_loss: 0.0946 - val_accuracy: 0.9781
# Epoch 15/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0071 - accuracy: 0.9985 - val_loss: 0.0998 - val_accuracy: 0.9788
# Epoch 16/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0048 - accuracy: 0.9991 - val_loss: 0.0991 - val_accuracy: 0.9773
# Epoch 17/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0038 - accuracy: 0.9991 - val_loss: 0.1010 - val_accuracy: 0.9782
# Epoch 18/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0029 - accuracy: 0.9993 - val_loss: 0.1069 - val_accuracy: 0.9774
# Epoch 19/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 0.1083 - val_accuracy: 0.9776
# Epoch 20/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.1121 - val_accuracy: 0.9779
# Epoch 21/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0016 - accuracy: 0.9998 - val_loss: 0.1221 - val_accuracy: 0.9767
# Epoch 22/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0014 - accuracy: 0.9995 - val_loss: 0.1202 - val_accuracy: 0.9778
# Epoch 23/100
# 375/375 [==============================] - 1s 3ms/step - loss: 9.2449e-04 - accuracy: 0.9999 - val_loss: 0.1163 - val_accuracy: 0.9784
# Epoch 24/100
# 375/375 [==============================] - 1s 3ms/step - loss: 7.8848e-04 - accuracy: 0.9999 - val_loss: 0.1209 - val_accuracy: 0.9780
# Epoch 25/100
# 375/375 [==============================] - 1s 3ms/step - loss: 5.4885e-04 - accuracy: 0.9999 - val_loss: 0.1302 - val_accuracy: 0.9789
# Epoch 26/100
# 375/375 [==============================] - 1s 3ms/step - loss: 8.9730e-04 - accuracy: 0.9998 - val_loss: 0.1264 - val_accuracy: 0.9782
# Epoch 27/100
# 375/375 [==============================] - 1s 3ms/step - loss: 3.4053e-04 - accuracy: 1.0000 - val_loss: 0.1319 - val_accuracy: 0.9790
# Epoch 28/100
# 375/375 [==============================] - 1s 3ms/step - loss: 3.3968e-04 - accuracy: 0.9999 - val_loss: 0.1333 - val_accuracy: 0.9787
# Epoch 29/100
# 375/375 [==============================] - 1s 3ms/step - loss: 2.7980e-04 - accuracy: 1.0000 - val_loss: 0.1410 - val_accuracy: 0.9778
# Epoch 30/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.6973e-04 - accuracy: 1.0000 - val_loss: 0.1462 - val_accuracy: 0.9783
# Epoch 31/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.8839e-04 - accuracy: 1.0000 - val_loss: 0.1456 - val_accuracy: 0.9778
# Epoch 32/100
# 375/375 [==============================] - 1s 3ms/step - loss: 8.1028e-05 - accuracy: 1.0000 - val_loss: 0.1510 - val_accuracy: 0.9782
# Epoch 33/100
# 375/375 [==============================] - 1s 3ms/step - loss: 8.1431e-05 - accuracy: 1.0000 - val_loss: 0.1615 - val_accuracy: 0.9779
# Epoch 34/100
# 375/375 [==============================] - 1s 3ms/step - loss: 7.2900e-05 - accuracy: 1.0000 - val_loss: 0.1578 - val_accuracy: 0.9779
# Epoch 35/100
# 375/375 [==============================] - 1s 3ms/step - loss: 8.2410e-05 - accuracy: 1.0000 - val_loss: 0.1572 - val_accuracy: 0.9787
# Epoch 36/100
# 375/375 [==============================] - 1s 3ms/step - loss: 7.9045e-05 - accuracy: 1.0000 - val_loss: 0.1626 - val_accuracy: 0.9783
# Epoch 37/100
# 375/375 [==============================] - 1s 3ms/step - loss: 4.5464e-05 - accuracy: 1.0000 - val_loss: 0.1628 - val_accuracy: 0.9790
# Epoch 38/100
# 375/375 [==============================] - 1s 3ms/step - loss: 4.0802e-05 - accuracy: 1.0000 - val_loss: 0.1659 - val_accuracy: 0.9794
# Epoch 39/100
# 375/375 [==============================] - 1s 3ms/step - loss: 2.9201e-05 - accuracy: 1.0000 - val_loss: 0.1732 - val_accuracy: 0.9785
# Epoch 40/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.9233e-05 - accuracy: 1.0000 - val_loss: 0.1732 - val_accuracy: 0.9782
# Epoch 41/100
# 375/375 [==============================] - 1s 3ms/step - loss: 2.8381e-05 - accuracy: 1.0000 - val_loss: 0.1732 - val_accuracy: 0.9792
# Epoch 42/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.2252e-05 - accuracy: 1.0000 - val_loss: 0.1797 - val_accuracy: 0.9785
# Epoch 43/100
# 375/375 [==============================] - 1s 3ms/step - loss: 8.8638e-06 - accuracy: 1.0000 - val_loss: 0.1781 - val_accuracy: 0.9787
# Epoch 44/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.0988e-05 - accuracy: 1.0000 - val_loss: 0.1916 - val_accuracy: 0.9787
# Epoch 45/100
# 375/375 [==============================] - 1s 3ms/step - loss: 6.7554e-06 - accuracy: 1.0000 - val_loss: 0.1858 - val_accuracy: 0.9797
# Epoch 46/100
# 375/375 [==============================] - 1s 3ms/step - loss: 3.5799e-06 - accuracy: 1.0000 - val_loss: 0.1884 - val_accuracy: 0.9792
# Epoch 47/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.3016e-06 - accuracy: 1.0000 - val_loss: 0.1989 - val_accuracy: 0.9781
# Epoch 48/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.4076e-06 - accuracy: 1.0000 - val_loss: 0.1908 - val_accuracy: 0.9787
# Epoch 49/100
# 375/375 [==============================] - 1s 3ms/step - loss: 7.7018e-07 - accuracy: 1.0000 - val_loss: 0.2006 - val_accuracy: 0.9774
# Epoch 50/100
# 375/375 [==============================] - 1s 3ms/step - loss: 2.2154e-07 - accuracy: 1.0000 - val_loss: 0.1987 - val_accuracy: 0.9795
# Epoch 51/100
# 375/375 [==============================] - 1s 3ms/step - loss: 3.0854e-07 - accuracy: 1.0000 - val_loss: 0.1962 - val_accuracy: 0.9797
# Epoch 52/100
# 375/375 [==============================] - 1s 3ms/step - loss: 9.8114e-08 - accuracy: 1.0000 - val_loss: 0.1987 - val_accuracy: 0.9799
# Epoch 53/100
# 375/375 [==============================] - 1s 3ms/step - loss: 6.0645e-08 - accuracy: 1.0000 - val_loss: 0.1991 - val_accuracy: 0.9795
# Epoch 54/100
# 375/375 [==============================] - 1s 3ms/step - loss: 5.4860e-08 - accuracy: 1.0000 - val_loss: 0.2007 - val_accuracy: 0.9799
# Epoch 55/100
# 375/375 [==============================] - 1s 3ms/step - loss: 3.9318e-08 - accuracy: 1.0000 - val_loss: 0.1996 - val_accuracy: 0.9800
# Epoch 56/100
# 375/375 [==============================] - 1s 3ms/step - loss: 3.8350e-08 - accuracy: 1.0000 - val_loss: 0.2012 - val_accuracy: 0.9798
# Epoch 57/100
# 375/375 [==============================] - 1s 3ms/step - loss: 3.2193e-08 - accuracy: 1.0000 - val_loss: 0.2015 - val_accuracy: 0.9802
# Epoch 58/100
# 375/375 [==============================] - 1s 3ms/step - loss: 3.0464e-08 - accuracy: 1.0000 - val_loss: 0.2024 - val_accuracy: 0.9803
# Epoch 59/100
# 375/375 [==============================] - 1s 3ms/step - loss: 2.8853e-08 - accuracy: 1.0000 - val_loss: 0.2033 - val_accuracy: 0.9799
# Epoch 60/100
# 375/375 [==============================] - 1s 3ms/step - loss: 2.6411e-08 - accuracy: 1.0000 - val_loss: 0.2035 - val_accuracy: 0.9803
# Epoch 61/100
# 375/375 [==============================] - 1s 3ms/step - loss: 2.4296e-08 - accuracy: 1.0000 - val_loss: 0.2036 - val_accuracy: 0.9803
# Epoch 62/100
# 375/375 [==============================] - 1s 3ms/step - loss: 2.3402e-08 - accuracy: 1.0000 - val_loss: 0.2048 - val_accuracy: 0.9803
# Epoch 63/100
# 375/375 [==============================] - 1s 3ms/step - loss: 2.0704e-08 - accuracy: 1.0000 - val_loss: 0.2059 - val_accuracy: 0.9799
# Epoch 64/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.9909e-08 - accuracy: 1.0000 - val_loss: 0.2059 - val_accuracy: 0.9802
# Epoch 65/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.9400e-08 - accuracy: 1.0000 - val_loss: 0.2063 - val_accuracy: 0.9802
# Epoch 66/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.9444e-08 - accuracy: 1.0000 - val_loss: 0.2073 - val_accuracy: 0.9799
# Epoch 67/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.7680e-08 - accuracy: 1.0000 - val_loss: 0.2070 - val_accuracy: 0.9802
# Epoch 68/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.6725e-08 - accuracy: 1.0000 - val_loss: 0.2075 - val_accuracy: 0.9803
# Epoch 69/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.7243e-08 - accuracy: 1.0000 - val_loss: 0.2081 - val_accuracy: 0.9802
# Epoch 70/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.5287e-08 - accuracy: 1.0000 - val_loss: 0.2081 - val_accuracy: 0.9802
# Epoch 71/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.5019e-08 - accuracy: 1.0000 - val_loss: 0.2085 - val_accuracy: 0.9801
# Epoch 72/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.4113e-08 - accuracy: 1.0000 - val_loss: 0.2090 - val_accuracy: 0.9802
# Epoch 73/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.4639e-08 - accuracy: 1.0000 - val_loss: 0.2099 - val_accuracy: 0.9803
# Epoch 74/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.3779e-08 - accuracy: 1.0000 - val_loss: 0.2102 - val_accuracy: 0.9803
# Epoch 75/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.3036e-08 - accuracy: 1.0000 - val_loss: 0.2099 - val_accuracy: 0.9803
# Epoch 76/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.2438e-08 - accuracy: 1.0000 - val_loss: 0.2105 - val_accuracy: 0.9803
# Epoch 77/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.2907e-08 - accuracy: 1.0000 - val_loss: 0.2110 - val_accuracy: 0.9803
# Epoch 78/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.2112e-08 - accuracy: 1.0000 - val_loss: 0.2110 - val_accuracy: 0.9804
# Epoch 79/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.1317e-08 - accuracy: 1.0000 - val_loss: 0.2117 - val_accuracy: 0.9803
# Epoch 80/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.0908e-08 - accuracy: 1.0000 - val_loss: 0.2121 - val_accuracy: 0.9803
# Epoch 81/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.0788e-08 - accuracy: 1.0000 - val_loss: 0.2121 - val_accuracy: 0.9804
# Epoch 82/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.0621e-08 - accuracy: 1.0000 - val_loss: 0.2123 - val_accuracy: 0.9803
# Epoch 83/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.0068e-08 - accuracy: 1.0000 - val_loss: 0.2129 - val_accuracy: 0.9801
# Epoch 84/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.0619e-08 - accuracy: 1.0000 - val_loss: 0.2132 - val_accuracy: 0.9803
# Epoch 85/100
# 375/375 [==============================] - 1s 3ms/step - loss: 9.8402e-09 - accuracy: 1.0000 - val_loss: 0.2135 - val_accuracy: 0.9804
# Epoch 86/100
# 375/375 [==============================] - 1s 3ms/step - loss: 1.0118e-08 - accuracy: 1.0000 - val_loss: 0.2139 - val_accuracy: 0.9804
# Epoch 87/100
# 375/375 [==============================] - 1s 3ms/step - loss: 9.7591e-09 - accuracy: 1.0000 - val_loss: 0.2144 - val_accuracy: 0.9803
# Epoch 88/100
# 375/375 [==============================] - 1s 3ms/step - loss: 9.7142e-09 - accuracy: 1.0000 - val_loss: 0.2142 - val_accuracy: 0.9804
# Epoch 89/100
# 375/375 [==============================] - 1s 3ms/step - loss: 9.0920e-09 - accuracy: 1.0000 - val_loss: 0.2144 - val_accuracy: 0.9803
# Epoch 90/100
# 375/375 [==============================] - 1s 3ms/step - loss: 8.7993e-09 - accuracy: 1.0000 - val_loss: 0.2150 - val_accuracy: 0.9803
# Epoch 91/100
# 375/375 [==============================] - 1s 3ms/step - loss: 9.1493e-09 - accuracy: 1.0000 - val_loss: 0.2151 - val_accuracy: 0.9803
# Epoch 92/100
# 375/375 [==============================] - 1s 3ms/step - loss: 8.5113e-09 - accuracy: 1.0000 - val_loss: 0.2152 - val_accuracy: 0.9803
# Epoch 93/100
# 375/375 [==============================] - 1s 3ms/step - loss: 8.6878e-09 - accuracy: 1.0000 - val_loss: 0.2156 - val_accuracy: 0.9803
# Epoch 94/100
# 375/375 [==============================] - 1s 3ms/step - loss: 8.4701e-09 - accuracy: 1.0000 - val_loss: 0.2159 - val_accuracy: 0.9803
# Epoch 95/100
# 375/375 [==============================] - 1s 3ms/step - loss: 8.4526e-09 - accuracy: 1.0000 - val_loss: 0.2163 - val_accuracy: 0.9802
# Epoch 96/100
# 375/375 [==============================] - 1s 3ms/step - loss: 8.2773e-09 - accuracy: 1.0000 - val_loss: 0.2163 - val_accuracy: 0.9803
# Epoch 97/100
# 375/375 [==============================] - 1s 3ms/step - loss: 7.8512e-09 - accuracy: 1.0000 - val_loss: 0.2168 - val_accuracy: 0.9801
# Epoch 98/100
# 375/375 [==============================] - 1s 3ms/step - loss: 7.9246e-09 - accuracy: 1.0000 - val_loss: 0.2167 - val_accuracy: 0.9803
# Epoch 99/100
# 375/375 [==============================] - 1s 3ms/step - loss: 7.7263e-09 - accuracy: 1.0000 - val_loss: 0.2170 - val_accuracy: 0.9802
# Epoch 100/100
# 375/375 [==============================] - 1s 3ms/step - loss: 7.5993e-09 - accuracy: 1.0000 - val_loss: 0.2174 - val_accuracy: 0.9801
# CPU times: user 1min 52s, sys: 17.3 s, total: 2min 10s
# Wall time: 1min 46s

# %% [markdown]
# > ## 4) 학습 결과 시각화 - Overfitting

# %% [markdown]
# * Loss Visualization

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_mnist.history['loss']) + 1)

plt.figure(figsize = (9, 6))
plt.plot(epochs, Hist_mnist.history['loss'])
plt.plot(epochs, Hist_mnist.history['val_loss'])
plt.ylim(0, 0.4)
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()
plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %% [markdown]
# * Loss & Accuracy

# %%
loss, accuracy = mnist.evaluate(X_test, y_test)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1813 - accuracy: 0.9801
# Loss = 0.18125
# Accuracy = 0.98010

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
