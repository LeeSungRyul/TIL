# %% [markdown]
# # MNIST - Categorical Classification
# > # L2 Regularization
# ## Import Tensorflow & Keras

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# * import Keras

# %%
import keras

keras.__version__
# Out:
# '2.4.3'

# %% [markdown]
# # I. MNIST Data_Set Load

# %%
from keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# # II. Data Preprocessing

# %% [markdown]
# > ## 1) Reshape and Normalization

# %% [markdown]
# * reshape

# %%
X_train = X_train.reshape((60000, 28 * 28))
X_test = X_test.reshape((10000, 28 * 28))

# %% [markdown]
# * Normalization

# %%
X_train = X_train.astype(float) / 255
X_test = X_test.astype(float) / 255

# %% [markdown]
# > ## 2) One Hot Encoding

# %%
from keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# # III. MNIST Keras Modeling

# %% [markdown]
# > ## 1) Model Define

# %% [markdown]
# * 모델 신경망 구조 정의
#  - 2개의 Hidden Layers & 768개의 Nodes
#  - Model Capacity는 기존과 동일
#  - L2 Regularization 적용

# %%
from keras import models
from keras import layers
from keras import regularizers

mnist = models.Sequential()
mnist.add(layers.Dense(512, activation = 'relu',
                       kernel_regularizer = regularizers.l2(0.00001),
                       input_shape=(28 * 28,)))
mnist.add(layers.Dense(256, activation = 'relu',
                       kernel_regularizer = regularizers.l2(0.00001)))
mnist.add(layers.Dense(10, activation = 'softmax'))

# %% [markdown]
# * 모델 구조 확인

# %%
mnist.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               401920
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 535,818
# Trainable params: 535,818
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %% [markdown]
# * 모델 학습방법 설정

# %%
mnist.compile(loss = 'categorical_crossentropy',
              optimizer = 'rmsprop',
              metrics = ['accuracy'])

# %% [markdown]
# > ## 3) Model Fit

# %% [markdown]
# * 약 3분

# %%
# %%time

Hist_mnist = mnist.fit(X_train, y_train,
                       epochs = 100,
                       batch_size = 128,
                       validation_split = 0.2)
# Out:
# Epoch 1/100
# 375/375 [==============================] - 5s 4ms/step - loss: 0.4725 - accuracy: 0.8529 - val_loss: 0.1264 - val_accuracy: 0.9643
# Epoch 2/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.1090 - accuracy: 0.9697 - val_loss: 0.1158 - val_accuracy: 0.9678
# Epoch 3/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0682 - accuracy: 0.9820 - val_loss: 0.1182 - val_accuracy: 0.9686
# Epoch 4/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0527 - accuracy: 0.9860 - val_loss: 0.1042 - val_accuracy: 0.9740
# Epoch 5/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0412 - accuracy: 0.9905 - val_loss: 0.1029 - val_accuracy: 0.9768
# Epoch 6/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0359 - accuracy: 0.9921 - val_loss: 0.1071 - val_accuracy: 0.9757
# Epoch 7/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0294 - accuracy: 0.9942 - val_loss: 0.1057 - val_accuracy: 0.9788
# Epoch 8/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0274 - accuracy: 0.9942 - val_loss: 0.1153 - val_accuracy: 0.9743
# Epoch 9/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0245 - accuracy: 0.9953 - val_loss: 0.1082 - val_accuracy: 0.9778
# Epoch 10/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0243 - accuracy: 0.9956 - val_loss: 0.1319 - val_accuracy: 0.9734
# Epoch 11/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0241 - accuracy: 0.9957 - val_loss: 0.1115 - val_accuracy: 0.9793
# Epoch 12/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0236 - accuracy: 0.9958 - val_loss: 0.1168 - val_accuracy: 0.9786
# Epoch 13/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0202 - accuracy: 0.9966 - val_loss: 0.1281 - val_accuracy: 0.9756
# Epoch 14/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0207 - accuracy: 0.9966 - val_loss: 0.1174 - val_accuracy: 0.9789
# Epoch 15/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0197 - accuracy: 0.9968 - val_loss: 0.1257 - val_accuracy: 0.9767
# Epoch 16/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0186 - accuracy: 0.9966 - val_loss: 0.1660 - val_accuracy: 0.9722
# Epoch 17/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0195 - accuracy: 0.9968 - val_loss: 0.1335 - val_accuracy: 0.9767
# Epoch 18/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0171 - accuracy: 0.9973 - val_loss: 0.1112 - val_accuracy: 0.9786
# Epoch 19/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0168 - accuracy: 0.9977 - val_loss: 0.1339 - val_accuracy: 0.9759
# Epoch 20/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0167 - accuracy: 0.9974 - val_loss: 0.1478 - val_accuracy: 0.9765
# Epoch 21/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0172 - accuracy: 0.9976 - val_loss: 0.1455 - val_accuracy: 0.9760
# Epoch 22/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0167 - accuracy: 0.9973 - val_loss: 0.1313 - val_accuracy: 0.9774
# Epoch 23/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0146 - accuracy: 0.9979 - val_loss: 0.1268 - val_accuracy: 0.9783
# Epoch 24/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0163 - accuracy: 0.9973 - val_loss: 0.1236 - val_accuracy: 0.9773
# Epoch 25/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0155 - accuracy: 0.9976 - val_loss: 0.1441 - val_accuracy: 0.9756
# Epoch 26/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0175 - accuracy: 0.9969 - val_loss: 0.1218 - val_accuracy: 0.9803
# Epoch 27/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0143 - accuracy: 0.9979 - val_loss: 0.1303 - val_accuracy: 0.9802
# Epoch 28/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0151 - accuracy: 0.9976 - val_loss: 0.1224 - val_accuracy: 0.9797
# Epoch 29/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0135 - accuracy: 0.9981 - val_loss: 0.1314 - val_accuracy: 0.9789
# Epoch 30/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0168 - accuracy: 0.9973 - val_loss: 0.1270 - val_accuracy: 0.9800
# Epoch 31/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0148 - accuracy: 0.9975 - val_loss: 0.1438 - val_accuracy: 0.9775
# Epoch 32/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0143 - accuracy: 0.9981 - val_loss: 0.1428 - val_accuracy: 0.9775
# Epoch 33/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0145 - accuracy: 0.9977 - val_loss: 0.1451 - val_accuracy: 0.9763
# Epoch 34/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0135 - accuracy: 0.9980 - val_loss: 0.1277 - val_accuracy: 0.9794
# Epoch 35/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0142 - accuracy: 0.9979 - val_loss: 0.1348 - val_accuracy: 0.9779
# Epoch 36/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0126 - accuracy: 0.9983 - val_loss: 0.1395 - val_accuracy: 0.9778
# Epoch 37/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0123 - accuracy: 0.9984 - val_loss: 0.1253 - val_accuracy: 0.9784
# Epoch 38/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0137 - accuracy: 0.9980 - val_loss: 0.1546 - val_accuracy: 0.9752
# Epoch 39/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0162 - accuracy: 0.9972 - val_loss: 0.1274 - val_accuracy: 0.9784
# Epoch 40/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0124 - accuracy: 0.9982 - val_loss: 0.1364 - val_accuracy: 0.9784
# Epoch 41/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0119 - accuracy: 0.9983 - val_loss: 0.1384 - val_accuracy: 0.9797
# Epoch 42/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0120 - accuracy: 0.9983 - val_loss: 0.1407 - val_accuracy: 0.9781
# Epoch 43/100
# 375/375 [==============================] - 1s 4ms/step - loss: 0.0138 - accuracy: 0.9978 - val_loss: 0.1308 - val_accuracy: 0.9794
# Epoch 44/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0121 - accuracy: 0.9983 - val_loss: 0.1554 - val_accuracy: 0.9744
# Epoch 45/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0142 - accuracy: 0.9975 - val_loss: 0.1422 - val_accuracy: 0.9781
# Epoch 46/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0112 - accuracy: 0.9985 - val_loss: 0.1390 - val_accuracy: 0.9777
# Epoch 47/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0119 - accuracy: 0.9983 - val_loss: 0.1283 - val_accuracy: 0.9794
# Epoch 48/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0124 - accuracy: 0.9979 - val_loss: 0.1303 - val_accuracy: 0.9785
# Epoch 49/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0110 - accuracy: 0.9985 - val_loss: 0.1324 - val_accuracy: 0.9790
# Epoch 50/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0110 - accuracy: 0.9984 - val_loss: 0.1528 - val_accuracy: 0.9744
# Epoch 51/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0119 - accuracy: 0.9978 - val_loss: 0.1331 - val_accuracy: 0.9787
# Epoch 52/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0115 - accuracy: 0.9982 - val_loss: 0.1305 - val_accuracy: 0.9793
# Epoch 53/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0117 - accuracy: 0.9982 - val_loss: 0.1516 - val_accuracy: 0.9764
# Epoch 54/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0121 - accuracy: 0.9983 - val_loss: 0.1448 - val_accuracy: 0.9790
# Epoch 55/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0126 - accuracy: 0.9982 - val_loss: 0.1319 - val_accuracy: 0.9793
# Epoch 56/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0103 - accuracy: 0.9984 - val_loss: 0.1357 - val_accuracy: 0.9785
# Epoch 57/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0108 - accuracy: 0.9986 - val_loss: 0.1420 - val_accuracy: 0.9768
# Epoch 58/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0104 - accuracy: 0.9987 - val_loss: 0.1362 - val_accuracy: 0.9808
# Epoch 59/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0116 - accuracy: 0.9980 - val_loss: 0.1374 - val_accuracy: 0.9793
# Epoch 60/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0102 - accuracy: 0.9985 - val_loss: 0.1858 - val_accuracy: 0.9711
# Epoch 61/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0113 - accuracy: 0.9982 - val_loss: 0.1343 - val_accuracy: 0.9801
# Epoch 62/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0122 - accuracy: 0.9985 - val_loss: 0.1365 - val_accuracy: 0.9797
# Epoch 63/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0118 - accuracy: 0.9980 - val_loss: 0.1452 - val_accuracy: 0.9784
# Epoch 64/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0107 - accuracy: 0.9984 - val_loss: 0.1745 - val_accuracy: 0.9743
# Epoch 65/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0107 - accuracy: 0.9982 - val_loss: 0.1570 - val_accuracy: 0.9776
# Epoch 66/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0123 - accuracy: 0.9979 - val_loss: 0.1376 - val_accuracy: 0.9789
# Epoch 67/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0111 - accuracy: 0.9982 - val_loss: 0.1772 - val_accuracy: 0.9734
# Epoch 68/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0103 - accuracy: 0.9984 - val_loss: 0.1448 - val_accuracy: 0.9769
# Epoch 69/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0102 - accuracy: 0.9985 - val_loss: 0.1321 - val_accuracy: 0.9801
# Epoch 70/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0103 - accuracy: 0.9985 - val_loss: 0.1562 - val_accuracy: 0.9757
# Epoch 71/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0106 - accuracy: 0.9983 - val_loss: 0.1716 - val_accuracy: 0.9744
# Epoch 72/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0110 - accuracy: 0.9983 - val_loss: 0.1613 - val_accuracy: 0.9761
# Epoch 73/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0101 - accuracy: 0.9984 - val_loss: 0.1536 - val_accuracy: 0.9762
# Epoch 74/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0115 - accuracy: 0.9981 - val_loss: 0.1487 - val_accuracy: 0.9762
# Epoch 75/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0102 - accuracy: 0.9985 - val_loss: 0.1547 - val_accuracy: 0.9802
# Epoch 76/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0111 - accuracy: 0.9977 - val_loss: 0.1583 - val_accuracy: 0.9778
# Epoch 77/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0102 - accuracy: 0.9984 - val_loss: 0.1539 - val_accuracy: 0.9768
# Epoch 78/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0104 - accuracy: 0.9981 - val_loss: 0.1334 - val_accuracy: 0.9801
# Epoch 79/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0099 - accuracy: 0.9985 - val_loss: 0.1468 - val_accuracy: 0.9780
# Epoch 80/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0101 - accuracy: 0.9983 - val_loss: 0.1475 - val_accuracy: 0.9795
# Epoch 81/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0093 - accuracy: 0.9987 - val_loss: 0.1539 - val_accuracy: 0.9794
# Epoch 82/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0097 - accuracy: 0.9983 - val_loss: 0.1489 - val_accuracy: 0.9784
# Epoch 83/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0093 - accuracy: 0.9987 - val_loss: 0.1497 - val_accuracy: 0.9777
# Epoch 84/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0092 - accuracy: 0.9987 - val_loss: 0.1557 - val_accuracy: 0.9789
# Epoch 85/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0114 - accuracy: 0.9980 - val_loss: 0.1513 - val_accuracy: 0.9797
# Epoch 86/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0103 - accuracy: 0.9986 - val_loss: 0.1346 - val_accuracy: 0.9793
# Epoch 87/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0098 - accuracy: 0.9987 - val_loss: 0.1590 - val_accuracy: 0.9777
# Epoch 88/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0112 - accuracy: 0.9979 - val_loss: 0.1525 - val_accuracy: 0.9779
# Epoch 89/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0107 - accuracy: 0.9983 - val_loss: 0.1469 - val_accuracy: 0.9778
# Epoch 90/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0116 - accuracy: 0.9980 - val_loss: 0.1606 - val_accuracy: 0.9758
# Epoch 91/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0113 - accuracy: 0.9980 - val_loss: 0.1582 - val_accuracy: 0.9778
# Epoch 92/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0116 - accuracy: 0.9982 - val_loss: 0.1659 - val_accuracy: 0.9783
# Epoch 93/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0095 - accuracy: 0.9985 - val_loss: 0.1455 - val_accuracy: 0.9795
# Epoch 94/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0088 - accuracy: 0.9988 - val_loss: 0.1678 - val_accuracy: 0.9758
# Epoch 95/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0099 - accuracy: 0.9984 - val_loss: 0.1507 - val_accuracy: 0.9789
# Epoch 96/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0098 - accuracy: 0.9984 - val_loss: 0.1625 - val_accuracy: 0.9753
# Epoch 97/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0098 - accuracy: 0.9983 - val_loss: 0.1565 - val_accuracy: 0.9786
# Epoch 98/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0103 - accuracy: 0.9983 - val_loss: 0.1757 - val_accuracy: 0.9748
# Epoch 99/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0096 - accuracy: 0.9984 - val_loss: 0.1438 - val_accuracy: 0.9780
# Epoch 100/100
# 375/375 [==============================] - 1s 3ms/step - loss: 0.0100 - accuracy: 0.9984 - val_loss: 0.1770 - val_accuracy: 0.9758
# CPU times: user 2min 9s, sys: 18.8 s, total: 2min 28s
# Wall time: 2min 2s

# %% [markdown]
# > ## 4) 학습 결과 시각화

# %% [markdown]
# * Loss Visualization

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_mnist.history['loss']) + 1)

plt.figure(figsize = (9, 6))
plt.plot(epochs, Hist_mnist.history['loss'])
plt.plot(epochs, Hist_mnist.history['val_loss'])
plt.ylim(0, 0.4)
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()
plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %% [markdown]
# * Loss & Accuracy

# %%
loss, accuracy = mnist.evaluate(X_test, y_test)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1573 - accuracy: 0.9784
# Loss = 0.15726
# Accuracy = 0.97840

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
