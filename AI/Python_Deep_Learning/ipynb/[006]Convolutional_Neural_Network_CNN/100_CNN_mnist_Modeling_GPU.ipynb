# %% [markdown]
# # MNIST - Categorical Classification
# > # Convolutional Neural Network
# ## Import Keras

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# * import Keras

# %%
import keras

keras.__version__
# Out:
# '2.4.3'

# %% [markdown]
# # I. MNIST Data_Set Load

# %%
from keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# # II. Data Preprocessing

# %% [markdown]
# > ## 1) Reshape and Normalization

# %% [markdown]
# * reshape

# %%
X_train = X_train.reshape((60000,  28, 28, 1))
X_test = X_test.reshape((10000,  28, 28, 1))

# %% [markdown]
# * Normalization

# %%
X_train = X_train.astype(float) / 255
X_test = X_test.astype(float) / 255

# %% [markdown]
# > ## 2) One Hot Encoding

# %%
from keras.utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# # III. MNIST Keras Modeling

# %% [markdown]
# > ## 1) Model Define

# %% [markdown]
# * Feature Extraction Layer

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

model = models.Sequential()
model.add(layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=(28, 28, 1)))
model.add(layers.MaxPool2D(pool_size=(2,2)))
model.add(layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu'))
model.add(layers.MaxPool2D(pool_size=(2,2)))
model.add(layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 3, 3, 64)          36928
# =================================================================
# Total params: 55,744
# Trainable params: 55,744
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# * Classification Layer

# %%
model.add(layers.Flatten())
model.add(layers.Dense(units=64, activation='relu'))
model.add(layers.Dense(units=10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 3, 3, 64)          36928
# _________________________________________________________________
# flatten (Flatten)            (None, 576)               0
# _________________________________________________________________
# dense (Dense)                (None, 64)                36928
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 93,322
# Trainable params: 93,322
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %% [markdown]
# * 모델 학습방법 설정

# %%
model.compile(loss = 'categorical_crossentropy',
              optimizer = 'rmsprop',
              metrics = ['accuracy'])

# %% [markdown]
# > ## 3) Model Fit

# %% [markdown]
# * 약 5분

# %%
# %%time

Hist_mnist = model.fit(X_train, y_train,
                       epochs = 100,
                       batch_size = 128,
                       validation_split = 0.2)
# Out:
# Epoch 1/100
# 375/375 [==============================] - 33s 6ms/step - loss: 0.6026 - accuracy: 0.7992 - val_loss: 0.0799 - val_accuracy: 0.9758
# Epoch 2/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0661 - accuracy: 0.9796 - val_loss: 0.0612 - val_accuracy: 0.9800
# Epoch 3/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0414 - accuracy: 0.9877 - val_loss: 0.0461 - val_accuracy: 0.9862
# Epoch 4/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0297 - accuracy: 0.9907 - val_loss: 0.0423 - val_accuracy: 0.9882
# Epoch 5/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0234 - accuracy: 0.9930 - val_loss: 0.0406 - val_accuracy: 0.9880
# Epoch 6/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0181 - accuracy: 0.9946 - val_loss: 0.0385 - val_accuracy: 0.9899
# Epoch 7/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0147 - accuracy: 0.9954 - val_loss: 0.0391 - val_accuracy: 0.9903
# Epoch 8/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0112 - accuracy: 0.9963 - val_loss: 0.0424 - val_accuracy: 0.9887
# Epoch 9/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0095 - accuracy: 0.9971 - val_loss: 0.0395 - val_accuracy: 0.9906
# Epoch 10/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0086 - accuracy: 0.9974 - val_loss: 0.0514 - val_accuracy: 0.9899
# Epoch 11/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0059 - accuracy: 0.9983 - val_loss: 0.0456 - val_accuracy: 0.9905
# Epoch 12/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0054 - accuracy: 0.9983 - val_loss: 0.0520 - val_accuracy: 0.9890
# Epoch 13/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0058 - accuracy: 0.9979 - val_loss: 0.0472 - val_accuracy: 0.9920
# Epoch 14/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0040 - accuracy: 0.9986 - val_loss: 0.0477 - val_accuracy: 0.9906
# Epoch 15/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0041 - accuracy: 0.9986 - val_loss: 0.0532 - val_accuracy: 0.9916
# Epoch 16/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0030 - accuracy: 0.9990 - val_loss: 0.0535 - val_accuracy: 0.9920
# Epoch 17/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0030 - accuracy: 0.9990 - val_loss: 0.0541 - val_accuracy: 0.9914
# Epoch 18/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.0668 - val_accuracy: 0.9895
# Epoch 19/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0027 - accuracy: 0.9989 - val_loss: 0.0577 - val_accuracy: 0.9917
# Epoch 20/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 0.0600 - val_accuracy: 0.9913
# Epoch 21/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.0715 - val_accuracy: 0.9902
# Epoch 22/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.0840 - val_accuracy: 0.9900
# Epoch 23/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0027 - accuracy: 0.9994 - val_loss: 0.0676 - val_accuracy: 0.9914
# Epoch 24/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0025 - accuracy: 0.9993 - val_loss: 0.0671 - val_accuracy: 0.9908
# Epoch 25/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.0631 - val_accuracy: 0.9920
# Epoch 26/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.0895 - val_accuracy: 0.9901
# Epoch 27/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0711 - val_accuracy: 0.9916
# Epoch 28/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0853 - val_accuracy: 0.9905
# Epoch 29/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0028 - accuracy: 0.9993 - val_loss: 0.0856 - val_accuracy: 0.9911
# Epoch 30/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0014 - accuracy: 0.9997 - val_loss: 0.0807 - val_accuracy: 0.9922
# Epoch 31/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0013 - accuracy: 0.9996 - val_loss: 0.0900 - val_accuracy: 0.9900
# Epoch 32/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.1123 - val_accuracy: 0.9898
# Epoch 33/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.0898 - val_accuracy: 0.9912
# Epoch 34/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 0.1204 - val_accuracy: 0.9888
# Epoch 35/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.1006 - val_accuracy: 0.9912
# Epoch 36/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.1099 - val_accuracy: 0.9909
# Epoch 37/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.1131 - val_accuracy: 0.9900
# Epoch 38/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.1102 - val_accuracy: 0.9912
# Epoch 39/100
# 375/375 [==============================] - 2s 4ms/step - loss: 5.7726e-04 - accuracy: 0.9998 - val_loss: 0.1173 - val_accuracy: 0.9909
# Epoch 40/100
# 375/375 [==============================] - 2s 5ms/step - loss: 8.8760e-04 - accuracy: 0.9997 - val_loss: 0.1078 - val_accuracy: 0.9912
# Epoch 41/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0016 - accuracy: 0.9995 - val_loss: 0.1285 - val_accuracy: 0.9912
# Epoch 42/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0026 - accuracy: 0.9995 - val_loss: 0.1073 - val_accuracy: 0.9911
# Epoch 43/100
# 375/375 [==============================] - 2s 5ms/step - loss: 7.5643e-04 - accuracy: 0.9998 - val_loss: 0.1057 - val_accuracy: 0.9914
# Epoch 44/100
# 375/375 [==============================] - 2s 5ms/step - loss: 9.8360e-04 - accuracy: 0.9998 - val_loss: 0.0998 - val_accuracy: 0.9924
# Epoch 45/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0011 - accuracy: 0.9999 - val_loss: 0.1256 - val_accuracy: 0.9912
# Epoch 46/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.1264 - val_accuracy: 0.9897
# Epoch 47/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.1219 - val_accuracy: 0.9917
# Epoch 48/100
# 375/375 [==============================] - 2s 4ms/step - loss: 6.6492e-04 - accuracy: 0.9998 - val_loss: 0.1358 - val_accuracy: 0.9912
# Epoch 49/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0022 - accuracy: 0.9997 - val_loss: 0.1389 - val_accuracy: 0.9905
# Epoch 50/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.1156 - val_accuracy: 0.9916
# Epoch 51/100
# 375/375 [==============================] - 2s 4ms/step - loss: 2.5462e-04 - accuracy: 0.9999 - val_loss: 0.1240 - val_accuracy: 0.9912
# Epoch 52/100
# 375/375 [==============================] - 2s 4ms/step - loss: 3.6330e-04 - accuracy: 0.9999 - val_loss: 0.1228 - val_accuracy: 0.9911
# Epoch 53/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.1495 - val_accuracy: 0.9898
# Epoch 54/100
# 375/375 [==============================] - 2s 4ms/step - loss: 8.9765e-04 - accuracy: 0.9998 - val_loss: 0.1203 - val_accuracy: 0.9922
# Epoch 55/100
# 375/375 [==============================] - 2s 4ms/step - loss: 6.8268e-04 - accuracy: 0.9999 - val_loss: 0.1370 - val_accuracy: 0.9917
# Epoch 56/100
# 375/375 [==============================] - 2s 4ms/step - loss: 9.5727e-04 - accuracy: 0.9999 - val_loss: 0.1234 - val_accuracy: 0.9918
# Epoch 57/100
# 375/375 [==============================] - 2s 4ms/step - loss: 4.6574e-04 - accuracy: 0.9998 - val_loss: 0.1525 - val_accuracy: 0.9903
# Epoch 58/100
# 375/375 [==============================] - 2s 5ms/step - loss: 9.8813e-04 - accuracy: 0.9997 - val_loss: 0.1475 - val_accuracy: 0.9910
# Epoch 59/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.1739 - val_accuracy: 0.9904
# Epoch 60/100
# 375/375 [==============================] - 2s 4ms/step - loss: 7.7739e-04 - accuracy: 0.9997 - val_loss: 0.1272 - val_accuracy: 0.9922
# Epoch 61/100
# 375/375 [==============================] - 2s 4ms/step - loss: 9.9565e-04 - accuracy: 0.9997 - val_loss: 0.1643 - val_accuracy: 0.9902
# Epoch 62/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.1440 - val_accuracy: 0.9912
# Epoch 63/100
# 375/375 [==============================] - 2s 5ms/step - loss: 2.1400e-04 - accuracy: 0.9999 - val_loss: 0.1461 - val_accuracy: 0.9911
# Epoch 64/100
# 375/375 [==============================] - 2s 4ms/step - loss: 4.5682e-04 - accuracy: 0.9999 - val_loss: 0.1421 - val_accuracy: 0.9912
# Epoch 65/100
# 375/375 [==============================] - 2s 4ms/step - loss: 8.2472e-04 - accuracy: 0.9997 - val_loss: 0.1494 - val_accuracy: 0.9915
# Epoch 66/100
# 375/375 [==============================] - 2s 4ms/step - loss: 4.2621e-04 - accuracy: 0.9999 - val_loss: 0.1547 - val_accuracy: 0.9911
# Epoch 67/100
# 375/375 [==============================] - 2s 4ms/step - loss: 4.2578e-04 - accuracy: 0.9999 - val_loss: 0.1552 - val_accuracy: 0.9899
# Epoch 68/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0019 - accuracy: 0.9996 - val_loss: 0.1482 - val_accuracy: 0.9912
# Epoch 69/100
# 375/375 [==============================] - 2s 4ms/step - loss: 4.0035e-04 - accuracy: 0.9999 - val_loss: 0.1376 - val_accuracy: 0.9918
# Epoch 70/100
# 375/375 [==============================] - 2s 4ms/step - loss: 4.7037e-04 - accuracy: 0.9999 - val_loss: 0.1474 - val_accuracy: 0.9917
# Epoch 71/100
# 375/375 [==============================] - 2s 4ms/step - loss: 5.9643e-04 - accuracy: 0.9998 - val_loss: 0.1547 - val_accuracy: 0.9918
# Epoch 72/100
# 375/375 [==============================] - 2s 4ms/step - loss: 5.4525e-04 - accuracy: 0.9999 - val_loss: 0.1577 - val_accuracy: 0.9918
# Epoch 73/100
# 375/375 [==============================] - 2s 4ms/step - loss: 6.1497e-04 - accuracy: 0.9999 - val_loss: 0.1516 - val_accuracy: 0.9914
# Epoch 74/100
# 375/375 [==============================] - 2s 4ms/step - loss: 3.7499e-04 - accuracy: 0.9999 - val_loss: 0.1634 - val_accuracy: 0.9919
# Epoch 75/100
# 375/375 [==============================] - 2s 4ms/step - loss: 4.1094e-04 - accuracy: 0.9998 - val_loss: 0.1733 - val_accuracy: 0.9914
# Epoch 76/100
# 375/375 [==============================] - 2s 4ms/step - loss: 5.8302e-04 - accuracy: 0.9999 - val_loss: 0.1716 - val_accuracy: 0.9912
# Epoch 77/100
# 375/375 [==============================] - 2s 4ms/step - loss: 2.8238e-04 - accuracy: 1.0000 - val_loss: 0.1822 - val_accuracy: 0.9907
# Epoch 78/100
# 375/375 [==============================] - 2s 4ms/step - loss: 7.0458e-04 - accuracy: 0.9999 - val_loss: 0.1662 - val_accuracy: 0.9917
# Epoch 79/100
# 375/375 [==============================] - 2s 5ms/step - loss: 5.3179e-04 - accuracy: 0.9999 - val_loss: 0.1675 - val_accuracy: 0.9916
# Epoch 80/100
# 375/375 [==============================] - 2s 5ms/step - loss: 4.8515e-04 - accuracy: 0.9998 - val_loss: 0.1972 - val_accuracy: 0.9901
# Epoch 81/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.1581 - val_accuracy: 0.9909
# Epoch 82/100
# 375/375 [==============================] - 2s 5ms/step - loss: 8.5607e-04 - accuracy: 0.9998 - val_loss: 0.1912 - val_accuracy: 0.9902
# Epoch 83/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 0.1656 - val_accuracy: 0.9917
# Epoch 84/100
# 375/375 [==============================] - 2s 5ms/step - loss: 2.6657e-04 - accuracy: 1.0000 - val_loss: 0.1906 - val_accuracy: 0.9908
# Epoch 85/100
# 375/375 [==============================] - 2s 5ms/step - loss: 2.5139e-04 - accuracy: 0.9999 - val_loss: 0.2010 - val_accuracy: 0.9906
# Epoch 86/100
# 375/375 [==============================] - 2s 4ms/step - loss: 7.1358e-04 - accuracy: 0.9997 - val_loss: 0.1671 - val_accuracy: 0.9925
# Epoch 87/100
# 375/375 [==============================] - 2s 4ms/step - loss: 1.7725e-04 - accuracy: 1.0000 - val_loss: 0.1787 - val_accuracy: 0.9914
# Epoch 88/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.1995 - val_accuracy: 0.9909
# Epoch 89/100
# 375/375 [==============================] - 2s 5ms/step - loss: 8.4657e-04 - accuracy: 0.9999 - val_loss: 0.1815 - val_accuracy: 0.9924
# Epoch 90/100
# 375/375 [==============================] - 2s 5ms/step - loss: 1.4503e-04 - accuracy: 1.0000 - val_loss: 0.1882 - val_accuracy: 0.9918
# Epoch 91/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.1829 - val_accuracy: 0.9923
# Epoch 92/100
# 375/375 [==============================] - 2s 5ms/step - loss: 3.6706e-05 - accuracy: 1.0000 - val_loss: 0.2114 - val_accuracy: 0.9911
# Epoch 93/100
# 375/375 [==============================] - 2s 5ms/step - loss: 4.6090e-04 - accuracy: 0.9999 - val_loss: 0.1774 - val_accuracy: 0.9916
# Epoch 94/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 0.1918 - val_accuracy: 0.9912
# Epoch 95/100
# 375/375 [==============================] - 2s 5ms/step - loss: 7.9800e-04 - accuracy: 0.9998 - val_loss: 0.2011 - val_accuracy: 0.9912
# Epoch 96/100
# 375/375 [==============================] - 2s 4ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.2039 - val_accuracy: 0.9914
# Epoch 97/100
# 375/375 [==============================] - 2s 5ms/step - loss: 7.9454e-04 - accuracy: 0.9999 - val_loss: 0.2182 - val_accuracy: 0.9912
# Epoch 98/100
# 375/375 [==============================] - 2s 5ms/step - loss: 4.5995e-04 - accuracy: 0.9999 - val_loss: 0.2309 - val_accuracy: 0.9904
# Epoch 99/100
# 375/375 [==============================] - 2s 4ms/step - loss: 2.0967e-04 - accuracy: 0.9999 - val_loss: 0.2459 - val_accuracy: 0.9912
# Epoch 100/100
# 375/375 [==============================] - 2s 5ms/step - loss: 0.0030 - accuracy: 0.9997 - val_loss: 0.2062 - val_accuracy: 0.9904
# CPU times: user 2min 54s, sys: 26.2 s, total: 3min 20s
# Wall time: 3min 19s

# %% [markdown]
# > ## 4) 학습 결과 시각화

# %% [markdown]
# * Loss Visualization

# %%
import matplotlib.pyplot as plt

epochs = range(1, len(Hist_mnist.history['loss']) + 1)

plt.figure(figsize = (9, 6))
plt.plot(epochs, Hist_mnist.history['loss'])
plt.plot(epochs, Hist_mnist.history['val_loss'])
plt.ylim(0, 0.4)
plt.title('Training & Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(['Training Loss', 'Validation Loss'])
plt.grid()
plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %% [markdown]
# * Loss & Accuracy

# %%
loss, accuracy = model.evaluate(X_test, y_test)

print('Loss = {:.5f}'.format(loss))
print('Accuracy = {:.5f}'.format(accuracy))
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1766 - accuracy: 0.9913
# Loss = 0.17657
# Accuracy = 0.99130

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
